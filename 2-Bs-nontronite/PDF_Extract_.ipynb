# %%
#!/usr/bin/env conda run -n newenv1 python
import sys
print(sys.executable)
# Out:
# C:\ProgramData\Anaconda3_1\envs\newenv1\python.exe

# %%
import numpy as np
import tabula
import pandas as pd
import PyPDF2
import re
import os
import warnings
import math
warnings.filterwarnings('ignore')
# warnings.filterwarnings(action='once')

# %%
# Navigate to http://visualstudio.microsoft.com/downloads. 
# Under the Tools for Visual Studio 2019 tab download the Build Tools for Visual Studio 2019. 
# You’ll then install the tools by checking the C++ build tools option box and clicking Install. 
# do NOT uncheck any of the automatically selected boxes.
# Run the following two commands in cmd mode under the venv you are working it:
# conda install -c conda-forge poppler
# pip install pdftotext
import pdftotext

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
import h5py

# %% [markdown]
# ### Inizio routine per dati tipo Testing lab

# %%
path = os.getcwd()+'\\DATA'

files=[]
filespath = []

for r,d,f in os.walk(path):
    for file in f:
        if '.pdf' in file:
            files.append(file)
            filespath.append(os.path.join(r,file))

# %%
def is_number(s):
    try:
        float(s)
        if math.isnan(float(s)):
            return False
        else: 
            return True
    except:
        return False

# %%
# funzione per il regex automatico

def findpattern (df,pattern):
    r=re.compile(pattern)
    for i in np.arange(0,df.shape[0],1):
        for e in np.arange(0,df.shape[1],1):
            if r.match (str(str(df.iloc[i,e]))):
                return df.iloc[i,e],i,e

# %%
def find_str2(stringtofind, Text, num):
    
    """ find the n° position string after the stringtofind present in a text"""
    
    posit = re.search(stringtofind, Text).start()
    list_str = re.split(' |\r|\n|,|:|;',Text[posit:posit+200])
    try:
        while True:
            list_str.remove('')
    except:
        pass
    return list_str[num]

# %%
def find_str(stringtofind, Text):
    
    """ find the string just after the stringtofind present in a text"""
    
    posit = re.search(stringtofind, Text.lower()).start()
    list_str = re.split(' |\r|\n|,|:|;',Text[posit:posit+200])
    try:
        while True:
            list_str.remove('')
    except:
        pass
    return list_str[1]

# %%
def new_df_row(pdf_file):
    
    file=files[filespath.index(pdf_file)]
    print(pdf_file)
    
    list_err = []
    
    try:
    
        df = tabula.read_pdf(pdf_file, pages=[1]) # cerca solo nella prima pagina
        
        #    0         1            2           3            4          5       6            7
        #['name','dry_weight','water_cont','void_ratio','degree_sat','UCS','elastic_mod','poisson',
        #   8        9         10      11       12       13       14        15
        #'data8','diameter','force','data11','data12','data13','rock_type','name_file'])

        lista0 = ['-','-','-','-','-','-','-','-','-','-','-','-','-','-','-', file]

        for i in np.arange(0,len(df),1):  # 'i' cicla tutte le tabelle
            
            for e in np.arange(0,df[i].shape[0],1):   # 'e' numero riga
                
                
                try:
                
                    #if 'power' in stringa1.lower():
                    #if re.search(r'\bpower\b', stringa1, re.I):     #per cercare power and not horsepower

                    if 'specimen' in str(df[i].iloc[e,0]).lower():         lista0[0] = str(df[i].iloc[0,1])   # nome del campione

                    elif 'dry unit' in str(df[i].iloc[e,0]).lower():         lista0[1] = str(df[i].iloc[e,2]) # Dry unit weight
                    elif 'water content'   in str(df[i].iloc[e,0]).lower():  lista0[2] = str(df[i].iloc[e,2]) # Water content
                    elif 'void ratio' in str(df[i].iloc[e,0]).lower():       lista0[3] = str(df[i].iloc[e,2]) # void ratio                 
                    elif 'saturation' in str(df[i].iloc[e,0]).lower():       lista0[4] = str(df[i].iloc[e,2]) # degree od saturation

                    elif 'unconfined compr' in str(df[i].iloc[e,0]).lower(): 
                        
                        if is_number(df[i].iloc[e+1,1]):                     lista0[5] = str(df[i].iloc[e+1,1]) # UCS 
                        elif is_number(df[i].iloc[e+1,0]):                   lista0[5] = str(df[i].iloc[e+1,0]) # UCS 
                        elif is_number(df[i].iloc[e,1]):                     lista0[5] = str(df[i].iloc[e,1]) # UCS 
                            
  
                    elif 'modulus' in str(df[i].iloc[e,0]).lower():
                        if is_number(df[i].iloc[e,1]):                       lista0[6] = str(df[i].iloc[e,1]) # modulus 
                        elif is_number(df[i].iloc[e+1,0]):                   lista0[6] = str(df[i].iloc[e+1,0]) # modulus                        
        
                    elif 'poisson' in str(df[i].iloc[e,0]).lower():
                
                        if is_number(df[i].iloc[e,1]):                       lista0[7] = str(df[i].iloc[e,1]) # poisson 
                        elif is_number(df[i].iloc[e+1,0]):                   lista0[7] = str(df[i].iloc[e+1,0]) # poisson                
                
                
                
                except:
                    
                    try:
                        
                        if 'dry unit' in str(df[i].iloc[e,0]).lower():  
                            for ee in str(df[i].iloc[e,0]).split(' '):
                                if is_number(ee):     lista0[1] = int(ee) # Dry unit weight  

                        elif 'water content' in str(df[i].iloc[e,0]).lower():  
                            for ee in str(df[i].iloc[e,0]).split(' '):
                                if is_number(ee):     lista0[2] = float(ee) # Water content  

                        elif 'void ratio' in str(df[i].iloc[e,0]).lower():  
                            for ee in str(df[i].iloc[e,0]).split(' '):
                                if is_number(ee):     lista0[3] = float(ee) # void ratio  

                        elif 'saturation' in str(df[i].iloc[e,0]).lower():  
                            for ee in str(df[i].iloc[e,0]).split(' '):
                                if is_number(ee):     lista0[4] = float(ee) # degree od saturation 
                    
                    except Exception as er1:
                        print('Table',i,'row',e,'Error1:',er1)             
                
    except Exception as er1:
        print('Error1:',er1)
        
        
    ## FIND ROCK TYPE
    
    with open(pdf_file, "rb") as f:
        pdf = pdftotext.PDF(f)
        
    Text = pdf[0].lower()   
    
    lista0[14] = find_str(r'description', Text)        
    
    try:
        # find water content

        try:
            str0 = find_str2('water content', Text.lower(), 1)
            if float(str0) >0.01: lista0[2] = str0
        except:
            pass
        try:
            str0 = find_str2('water content', Text.lower(), 2)
            if float(str0) >0.01: lista0[2] = str0 
        except:
            pass
        try:
            str0 = find_str2('water content', Text.lower(), 3)
            if float(str0) >0.01: lista0[2] = str0  
        except:
            pass

    except:
        print('water content string not found')

    try:
        # find dry density
        try:
            str1 = find_str2('unit weight', Text.lower(), 3)
            if float(str1) >1200: lista0[1] = str1
        except:
            pass
        try:
            str01 = find_str2('unit weight', Text.lower(), 2)
            if float(str1) >1200: lista0[1] = str1 
        except:
            pass
        try:
            str1 = find_str2('unit weight', Text.lower(), 1)
            if float(str1) >1200: lista0[1] = str1  
        except:
            pass  
    except:
        print('dry density string not found')
        
        
    try:
        # no.
        try:
            str1 = find_str2('no.', Text.lower(), 4)
            if '-' not in lista0[0] and '-' in str1: lista0[0] = str1
        except:
            pass
        try:
            str1 = find_str2('no.', Text.lower(), 3)
            if '-' not in lista0[0] and  '-' in str1: lista0[0] = str1
        except:
            pass
        try:
            str1 = find_str2('no.', Text.lower(), 2)
            if '-' not in lista0[0] and  '-' in str1: lista0[0] = str1
        except:
            pass  
        
    except:
        print('dry density string not found')
            
    return lista0

# %%
df1 = pd.DataFrame(columns=['name','dry_weight','water_cont','void_ratio','degree_sat','UCS','elastic_mod','poisson',
                            'data8','diameter','force','data11','data12','depth','rock_type','name_file'])


for file_path_ in filespath[:]:

    row_ls = new_df_row(file_path_)
    
    df1.loc[len(df1)]=row_ls
    
    
df1
# Out:
# C:\Users\fpe\JUPYTER\datirocce\2-Bs-nontronite\DATA\Modulus_B-1_EMR0000039.pdf
# C:\Users\fpe\JUPYTER\datirocce\2-Bs-nontronite\DATA\Modulus_B-2_EMR0000040.pdf
# C:\Users\fpe\JUPYTER\datirocce\2-Bs-nontronite\DATA\Modulus_B-3_EMR0000041.pdf
# C:\Users\fpe\JUPYTER\datirocce\2-Bs-nontronite\DATA\Modulus_B-4_EMR0000042.pdf
# C:\Users\fpe\JUPYTER\datirocce\2-Bs-nontronite\DATA\Modulus_B-5_EMR0000043.pdf
# C:\Users\fpe\JUPYTER\datirocce\2-Bs-nontronite\DATA\Modulus_B-6_EMR0000044.pdf
# C:\Users\fpe\JUPYTER\datirocce\2-Bs-nontronite\DATA\Modulus_BS-16_EMR0000030.pdf
# C:\Users\fpe\JUPYTER\datirocce\2-Bs-nontronite\DATA\UCS_BS-16 W_GEOR001657.pdf
# C:\Users\fpe\JUPYTER\datirocce\2-Bs-nontronite\DATA\UCS_BS-17 W_GEOR001655 .pdf
# C:\Users\fpe\JUPYTER\datirocce\2-Bs-nontronite\DATA\UCS_BS-18 W_GEOR001656 .pdf
# C:\Users\fpe\JUPYTER\datirocce\2-Bs-nontronite\DATA\UCS_C-1_GEOR001670.pdf
# C:\Users\fpe\JUPYTER\datirocce\2-Bs-nontronite\DATA\UCS_C-2_GEOR001671.pdf
# C:\Users\fpe\JUPYTER\datirocce\2-Bs-nontronite\DATA\UCS_C-3_GEOR001672.pdf
# C:\Users\fpe\JUPYTER\datirocce\2-Bs-nontronite\DATA\UCS_C-4_GEOR001673.pdf
# C:\Users\fpe\JUPYTER\datirocce\2-Bs-nontronite\DATA\UCS_C-5_GEOR001674.pdf
# C:\Users\fpe\JUPYTER\datirocce\2-Bs-nontronite\DATA\UCS_C-6_GEOR001675.pdf
#    name dry_weight water_cont void_ratio degree_sat    UCS elastic_mod  \
# 0   b-1       1926       7.92          -          -    9.5         1.1
# 1   b-2       1790      12.03          -          -    8.2         1.0
# 2   b-3       1781      13.68          -          -    6.3         1.0
# 3   b-4       1743      12.19          -          -    7.5         2.7
# 4   b-5       1788      12.71          -          -    8.0         1.2
# 5   b-6       1906      12.81          -          -    9.5         1.2
# 6     -       1774      10.54          -          -   11.2         2.7
# 7     -       1760          -          -          -   3.85           -
# 8     -       1737          -          -          -   3.38           -
# 9     -       1842          -          -          -   3.64           -
# 10  c-1       1874       10.9        nan        nan  10.48           -
# 11  c-2       1967        7.6        nan        nan  11.08           -
# 12  c-3       1718       12.6          -          -  10.43           -
# 13  c-4       1733       12.7          -          -  10.83           -
# 14  c-5       1770       12.9          -          -  11.83           -
# 15  c-6       1719       13.2          -          -  10.66           -
#
#    poisson data8 diameter force data11 data12 depth     rock_type  \
# 0     0.12     -        -     -      -      -     -    amigdaloid
# 1     0.19     -        -     -      -      -     -    amigdaloid
# 2     0.29     -        -     -      -      -     -    amigdaloid
# 3     0.13     -        -     -      -      -     -    amigdaloid
# 4     0.28     -        -     -      -      -     -    amigdaloid
# 5     0.28     -        -     -      -      -     -    amigdaloid
# 6     0.25     -        -     -      -      -     -          weak
# 7        -     -        -     -      -      -     -          weak
# 8        -     -        -     -      -      -     -          weak
# 9        -     -        -     -      -      -     -          weak
# 10       -     -        -     -      -      -     -  amygdaloidal
# 11       -     -        -     -      -      -     -  amygdaloidal
# 12       -     -        -     -      -      -     -  amygdaloidal
# 13       -     -        -     -      -      -     -  amygdaloidal
# 14       -     -        -     -      -      -     -  amygdaloidal
# 15       -     -        -     -      -      -     -  amygdaloidal
#
#                        name_file
# 0     Modulus_B-1_EMR0000039.pdf
# 1     Modulus_B-2_EMR0000040.pdf
# 2     Modulus_B-3_EMR0000041.pdf
# 3     Modulus_B-4_EMR0000042.pdf
# 4     Modulus_B-5_EMR0000043.pdf
# 5     Modulus_B-6_EMR0000044.pdf
# 6   Modulus_BS-16_EMR0000030.pdf
# 7     UCS_BS-16 W_GEOR001657.pdf
# 8    UCS_BS-17 W_GEOR001655 .pdf
# 9    UCS_BS-18 W_GEOR001656 .pdf
# 10        UCS_C-1_GEOR001670.pdf
# 11        UCS_C-2_GEOR001671.pdf
# 12        UCS_C-3_GEOR001672.pdf
# 13        UCS_C-4_GEOR001673.pdf
# 14        UCS_C-5_GEOR001674.pdf
# 15        UCS_C-6_GEOR001675.pdf

# %%
df1.to_hdf('df.h5', key='losses')

# %% [markdown]
# ### Inizio Routine per dati tipo Isotop

# %%
path = os.getcwd()+'\\DATA2'

files=[]
filespath = []

for r,d,f in os.walk(path):
    for file in f:
        if '.pdf' in file:
            files.append(file)
            filespath.append(os.path.join(r,file))

# %%
def new_df_row_pages(pdf_file, pagenum, Text):
    
    file=files[filespath.index(pdf_file)]+' page_{}'.format(pagenum)
    print(pdf_file)
    
    
    lista0 = ['-','-','-','-','-','-','-','-','-','-','-','-','-','-','-', file]
    
    try:     
        

        pagenum = int(pagenum)
        print('pagina: ', pagenum)
        df = tabula.read_pdf(pdf_file, pages=[pagenum])   # cicla per numero pagine "pagenum"

        #  0          1            2               3         4          5       6            7
        #['name','dry_weight','water_cont','void_ratio','degree_sat','UCS','elastic_mod','poisson',
        #   8        9          10     11       12       13       14         15
        #'data8','diameter','force','data11','data12','data13','rock_type','name_file'])
        
        try:
            for i in np.arange(0,len(df),1):                     # 'i' cicla tutte le tabelle
                

                for col in np.arange(0,df[i].shape[1],1):        # cicla i nomi delle colonne di ogni tabella
                    
                    if 'dry density' in df[i].columns[col].lower():
                        if int(df[i].iloc[-1,col])>1500:
                            lista0[1] = str(df[i].iloc[-1,col]) # Dry unit weight
                        elif int(df[i].iloc[-1,col-1])>1500:
                            lista0[1] = str(df[i].iloc[-1,col-1]) # Dry unit weight
                        else:
                            for xx in np.arange(0,df[i].shape[1],1):
                                if int(df[i].iloc[-1,xx])>1500: lista0[1] = str(df[i].iloc[-1,col])


                    
                    if 'unconfined' in str(df[i].columns[col]).lower():
                        lista0[5] = str(df[i].iloc[-1,col]) # UCS
                        
                    

                for row in np.arange(0,df[i].shape[0],1):

                    if 'average' in str(df[i].columns[col]).lower():
                        if 'modulus' in str(df[i].iloc[row,0]).lower():
                            lista0[6] = str(df[i].iloc[row,col]) # modulus
                        elif 'poisson' in str(df[i].iloc[row,0]).lower():
                            lista0[7] = str(df[i].iloc[row,col]) # modulus
        except Exception as er2:
            print('Error2:',er2)    

    except Exception as er1:
        print('Error1:\n',er1)
    
    try:
        posit = re.search(r"sample", Text).start()
        list_str = re.split(' |\r|\n|,|:|;',Text[posit:posit+60])
        try:
            while True:
                list_str.remove('')
        except:
            pass

        lista0[0] = list_str[1]
        
        # Exception for sample g-2 missing "sample" string impossible to find automatically
        # file is the filename
        
        if 'g-2' in Text.lower(): lista0[0]='g-2'
        
        try:
            # find the depth "depth, m: xxxx"
            
            try:
                stringtofind = r'm:'
                str2 = find_str2(stringtofind, Text)
                if float(str2)>0.01: lista0[13] = str2
            except:
                pass
            try:
                str4 = find_str2('depth, m', Text.lower(), 2)
                if float(str4) >0.01: lista0[13] = str4
            except:
                pass
            try:
                str4 = find_str2('depth, m', Text.lower(), 3)
                if float(str4) >0.01: lista0[13] = str4
            except:
                pass
            try:
                str4 = find_str2('depth, m', Text.lower(), 4)
                if float(str4) >0.01: lista0[13] = str4
            except:
                pass
                
            
        except:
            print('depth string not found')
            
        try:
            # find water content
            
            try:
                str0 = find_str2('water content', Text.lower(), 3)
                if float(str0) >0.01: lista0[2] = str0
            except:
                pass
            try:
                str0 = find_str2('water content', Text.lower(), 2)
                if float(str0) >0.01: lista0[2] = str0 
            except:
                pass
            try:
                str0 = find_str2('water content', Text.lower(), 2)
                if float(str0) >0.01: lista0[2] = str0  
            except:
                pass
                
        except:
            print('water content string not found')
            
        try:
            # find dry density
            try:
                str1 = find_str2('dry density', Text.lower(), 3)
                if float(str1) >1200: lista0[1] = str1
            except:
                pass
            try:
                str01 = find_str2('dry density', Text.lower(), 2)
                if float(str1) >1200: lista0[1] = str1 
            except:
                pass
            try:
                str1 = find_str2('dry density', Text.lower(), 2)
                if float(str1) >1200: lista0[1] = str1  
            except:
                pass  
        except:
            print('dry density string not found')
        
        
    except:
        print('failed to find a valid code')
            
    return lista0

# %%
df2 = pd.DataFrame(columns=['name','dry_weight','water_cont','void_ratio','degree_sat','UCS','elastic_mod','poisson',
                            'data8','diameter','force','data11','data12','depth','rock_type','name_file'])


for file_path_ in filespath[:]:
    
    with open(file_path_, "rb") as f:
        pdf = pdftotext.PDF(f)

    totpages = len(pdf)
    
    for pagenum in np.arange(1,totpages+1,1):
        
        pagenum = int(pagenum)  #otherwise numpyint32
        
        Text = pdf[pagenum-1].lower()

        row_ls = new_df_row_pages(file_path_,pagenum, Text)

        if row_ls[0] in df2.name.tolist():
            #print('found',row_ls[0])
            for xx in np.arange(1,df2.shape[1]-1,1):    
                if df2[df2.name==row_ls[0]][df2.columns[xx]].tolist()[0] == '-':
                    #print('new input',row_ls[xx])
                    df2.loc[df2.name==row_ls[0],df2.columns[xx]] = row_ls[xx]  
    
            
        elif row_ls[0] not in df2.name.tolist():
            #print(row_ls[0], 'first entry')
            df2.loc[len(df2)]=row_ls
            

           
#         if pagenum == 1:
#             break

df2
# Out:
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs31-bs42.pdf
# pagina:  1
# Got stderr: mar 21, 2020 2:29:44 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:29:45 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:29:45 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs31-bs42.pdf
# pagina:  2
# Got stderr: mar 21, 2020 2:29:45 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:29:45 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:29:45 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs31-bs42.pdf
# pagina:  3
# Got stderr: mar 21, 2020 2:29:46 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:29:46 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:29:46 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs31-bs42.pdf
# pagina:  4
# Got stderr: mar 21, 2020 2:29:47 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:29:48 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:29:48 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs31-bs42.pdf
# pagina:  5
# Got stderr: mar 21, 2020 2:29:48 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:29:49 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:29:49 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs31-bs42.pdf
# pagina:  6
# Got stderr: mar 21, 2020 2:29:49 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:29:50 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:29:50 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs31-bs42.pdf
# pagina:  7
# Got stderr: mar 21, 2020 2:29:50 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:29:51 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:29:51 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs31-bs42.pdf
# pagina:  8
# Got stderr: mar 21, 2020 2:29:51 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:29:52 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:29:52 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs31-bs42.pdf
# pagina:  9
# Got stderr: mar 21, 2020 2:29:53 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:29:53 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:29:53 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs31-bs42.pdf
# pagina:  10
# Got stderr: mar 21, 2020 2:29:54 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:29:54 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:29:54 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs31-bs42.pdf
# pagina:  11
# Got stderr: mar 21, 2020 2:29:55 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:29:55 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:29:55 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs31-bs42.pdf
# pagina:  12
# Got stderr: mar 21, 2020 2:29:56 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:29:56 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:29:56 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  1
# Got stderr: mar 21, 2020 2:29:57 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:29:57 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:29:57 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  2
# Got stderr: mar 21, 2020 2:29:58 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:29:58 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:29:58 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  3
# Got stderr: mar 21, 2020 2:29:59 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:29:59 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:29:59 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  4
# Got stderr: mar 21, 2020 2:30:00 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:00 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:00 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  5
# Got stderr: mar 21, 2020 2:30:01 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:01 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:01 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  6
# Got stderr: mar 21, 2020 2:30:02 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:02 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:02 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  7
# Got stderr: mar 21, 2020 2:30:03 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:03 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:03 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  8
# Got stderr: mar 21, 2020 2:30:04 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:04 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:04 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  9
# Got stderr: mar 21, 2020 2:30:05 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:05 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:05 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  10
# Got stderr: mar 21, 2020 2:30:06 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:06 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:06 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  11
# Got stderr: mar 21, 2020 2:30:07 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:07 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:07 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  12
# Got stderr: mar 21, 2020 2:30:08 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:08 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:08 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_H and G.pdf
# pagina:  1
# Got stderr: mar 21, 2020 2:30:09 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:09 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:09 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_H and G.pdf
# pagina:  2
# Got stderr: mar 21, 2020 2:30:10 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:10 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:10 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_H and G.pdf
# pagina:  3
# Got stderr: mar 21, 2020 2:30:11 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:11 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:11 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_H and G.pdf
# pagina:  4
# Got stderr: mar 21, 2020 2:30:12 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:12 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:12 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_H and G.pdf
# pagina:  5
# Got stderr: mar 21, 2020 2:30:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:13 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_H and G.pdf
# pagina:  6
# Got stderr: mar 21, 2020 2:30:14 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:14 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:14 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_H and G.pdf
# pagina:  7
# Got stderr: mar 21, 2020 2:30:15 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:15 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:15 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# failed to find a valid code
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_H and G.pdf
# pagina:  8
# Got stderr: mar 21, 2020 2:30:16 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:16 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:16 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_H and G.pdf
# pagina:  9
# Got stderr: mar 21, 2020 2:30:17 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:17 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:17 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_H and G.pdf
# pagina:  10
# Got stderr: mar 21, 2020 2:30:18 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:19 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:19 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_H and G.pdf
# pagina:  11
# Got stderr: mar 21, 2020 2:30:19 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_H and G.pdf
# pagina:  12
# Got stderr: mar 21, 2020 2:30:20 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:21 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:21 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_H and G.pdf
# pagina:  13
# Got stderr: mar 21, 2020 2:30:22 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:22 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:22 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_H and G.pdf
# pagina:  14
# Got stderr: mar 21, 2020 2:30:23 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:23 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:23 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_H and G.pdf
# pagina:  15
# Got stderr: mar 21, 2020 2:30:24 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:24 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:24 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\Modulus_H and G.pdf
# pagina:  16
# Got stderr: mar 21, 2020 2:30:25 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 81 (110) in font SymbolMT
# mar 21, 2020 2:30:25 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 80 (109) in font SymbolMT
# mar 21, 2020 2:30:25 AM org.apache.pdfbox.pdmodel.font.PDSimpleFont toUnicode
# AVVERTENZA: No Unicode mapping for 72 (101) in font SymbolMT
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs31-bs42.pdf
# pagina:  1
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs31-bs42.pdf
# pagina:  2
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs31-bs42.pdf
# pagina:  3
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs31-bs42.pdf
# pagina:  4
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs31-bs42.pdf
# pagina:  5
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs31-bs42.pdf
# pagina:  6
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs31-bs42.pdf
# pagina:  7
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs31-bs42.pdf
# pagina:  8
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs31-bs42.pdf
# pagina:  9
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs31-bs42.pdf
# pagina:  10
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs31-bs42.pdf
# pagina:  11
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs31-bs42.pdf
# pagina:  12
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  1
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  2
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  3
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  4
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  5
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  6
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  7
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  8
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  9
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  10
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  11
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_bs43-bs54_PH1D 42.25~33.25.pdf
# pagina:  12
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_H and G.pdf
# pagina:  1
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_H and G.pdf
# pagina:  2
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_H and G.pdf
# pagina:  3
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_H and G.pdf
# pagina:  4
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_H and G.pdf
# pagina:  5
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_H and G.pdf
# pagina:  6
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_H and G.pdf
# pagina:  7
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_H and G.pdf
# pagina:  8
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_H and G.pdf
# pagina:  9
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_H and G.pdf
# pagina:  10
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_H and G.pdf
# pagina:  11
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_H and G.pdf
# pagina:  12
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_H and G.pdf
# pagina:  13
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_H and G.pdf
# pagina:  14
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_H and G.pdf
# pagina:  15
# C:\Users\fpe\JUPYTER\datirocce\1-Bs-Strong & Bs-weak\DATA2\UCS_H and G.pdf
# pagina:  16
#      name dry_weight water_cont void_ratio degree_sat    UCS elastic_mod  \
# 0   bs-31       2752        1.0          -          -   60.7        62.3
# 1   bs-32       2819        0.5          -          -   87.1        70.3
# 2   bs-33       2719        1.3          -          -   62.0        52.5
# 3   bs-34       2744        0.9          -          -   95.6        75.1
# 4   bs-35       2813        0.6          -          -  150.0        62.1
# 5   bs-36       2792        0.7          -          -   40.4        72.1
# 6   bs-37       2799        0.8          -          -   67.2        67.8
# 7   bs-38       2743        1.3          -          -   80.1        55.8
# 8   bs-39       2685        1.8          -          -   63.7        46.4
# 9   bs-40       2756        0.9          -          -  158.5           -
# 10  bs-41       2755        1.1          -          -   38.2        38.7
# 11  bs-42       2742        1.1          -          -   73.0        55.6
# 12  bs-43       2874        0.8          -          -  158.9        69.1
# 13  bs-44       2875        0.6          -          -  131.9           -
# 14  bs-45       2851        1.0          -          -   54.6           -
# 15  bs-46       2873        0.8          -          -  127.2           -
# 16  bs-47       2879        0.7          -          -   65.2        89.2
# 17  bs-48       2914        0.6          -          -  121.8           -
# 18  bs-49       2917        0.6          -          -   93.7           -
# 19  bs-50       2872        0.8          -          -   95.0        57.9
# 20  bs-51       2910        0.5          -          -  136.8           -
# 21  bs-52       2868        0.7          -          -   61.8           -
# 22  bs-53       2866        0.9          -          -   87.0           -
# 23  bs-54       2806          -          -          -      -           -
# 24    h-1       2164        5.7          -          -   18.1        16.9
# 25    h-2       2164        5.8          -          -   17.3        10.1
# 26    h-3       2187        5.5          -          -   21.7        10.5
# 27    h-4       2291        3.7          -          -   18.0           -
# 28    h-5       2191        4.4          -          -    8.6           -
# 29    g-1       2163        4.9          -          -   17.0           -
# 30      -       1975          -          -          -      -        25.8
# 31    g-3       2069        5.7          -          -   11.7           -
# 32    g-4       2114        5.7          -          -   11.2           -
# 33    g-5       2147        6.0          -          -   20.9         2.6
# 34    g-6       2893        0.3          -          -   61.5           -
# 35    g-7       2887        0.5          -          -   64.6           -
# 36    g-8       2423        3.4          -          -   39.5           -
# 37    g-9       2619        2.1          -          -   45.0           -
# 38   g-10       2482        3.3          -          -   25.1           -
# 39   g-11       2745        0.8          -          -   49.8           -
# 40    g-2       1975        6.2          -          -   11.5           -
#
#    poisson data8 diameter force data11 data12  depth rock_type  \
# 0     0.23     -        -     -      -      -      -         -
# 1     0.24     -        -     -      -      -      -         -
# 2     0.14     -        -     -      -      -      -         -
# 3      0.2     -        -     -      -      -      -         -
# 4     0.24     -        -     -      -      -      -         -
# 5     0.23     -        -     -      -      -      -         -
# 6     0.28     -        -     -      -      -      -         -
# 7     0.23     -        -     -      -      -      -         -
# 8     0.14     -        -     -      -      -      -         -
# 9        -     -        -     -      -      -      -         -
# 10    0.21     -        -     -      -      -      -         -
# 11    0.26     -        -     -      -      -      -         -
# 12     0.2     -        -     -      -      -      -         -
# 13       -     -        -     -      -      -      -         -
# 14       -     -        -     -      -      -      -         -
# 15       -     -        -     -      -      -      -         -
# 16    0.37     -        -     -      -      -      -         -
# 17       -     -        -     -      -      -      -         -
# 18       -     -        -     -      -      -      -         -
# 19    0.26     -        -     -      -      -      -         -
# 20       -     -        -     -      -      -      -         -
# 21       -     -        -     -      -      -      -         -
# 22       -     -        -     -      -      -      -         -
# 23       -     -        -     -      -      -      -         -
# 24    0.37     -        -     -      -      -  12.15         -
# 25       -     -        -     -      -      -  13.30         -
# 26    0.11     -        -     -      -      -  12.40         -
# 27       -     -        -     -      -      -  14.15         -
# 28       -     -        -     -      -      -  14.35         -
# 29       -     -        -     -      -      -  18.20         -
# 30    0.04     -        -     -      -      -      -         -
# 31       -     -        -     -      -      -  18.60         -
# 32       -     -        -     -      -      -  18.80         -
# 33    0.19     -        -     -      -      -  19.00         -
# 34       -     -        -     -      -      -  35.80         -
# 35       -     -        -     -      -      -  36.70         -
# 36       -     -        -     -      -      -  40.65         -
# 37       -     -        -     -      -      -  40.85         -
# 38       -     -        -     -      -      -  41.00         -
# 39       -     -        -     -      -      -  47.55         -
# 40       -     -        -     -      -      -  18.40         -
#
#                                          name_file
# 0                     Modulus_bs31-bs42.pdf page_1
# 1                     Modulus_bs31-bs42.pdf page_2
# 2                     Modulus_bs31-bs42.pdf page_3
# 3                     Modulus_bs31-bs42.pdf page_4
# 4                     Modulus_bs31-bs42.pdf page_5
# 5                     Modulus_bs31-bs42.pdf page_6
# 6                     Modulus_bs31-bs42.pdf page_7
# 7                     Modulus_bs31-bs42.pdf page_8
# 8                     Modulus_bs31-bs42.pdf page_9
# 9                    Modulus_bs31-bs42.pdf page_10
# 10                   Modulus_bs31-bs42.pdf page_11
# 11                   Modulus_bs31-bs42.pdf page_12
# 12   Modulus_bs43-bs54_PH1D 42.25~33.25.pdf page_1
# 13   Modulus_bs43-bs54_PH1D 42.25~33.25.pdf page_2
# 14   Modulus_bs43-bs54_PH1D 42.25~33.25.pdf page_3
# 15   Modulus_bs43-bs54_PH1D 42.25~33.25.pdf page_4
# 16   Modulus_bs43-bs54_PH1D 42.25~33.25.pdf page_5
# 17   Modulus_bs43-bs54_PH1D 42.25~33.25.pdf page_6
# 18   Modulus_bs43-bs54_PH1D 42.25~33.25.pdf page_7
# 19   Modulus_bs43-bs54_PH1D 42.25~33.25.pdf page_8
# 20   Modulus_bs43-bs54_PH1D 42.25~33.25.pdf page_9
# 21  Modulus_bs43-bs54_PH1D 42.25~33.25.pdf page_10
# 22  Modulus_bs43-bs54_PH1D 42.25~33.25.pdf page_11
# 23  Modulus_bs43-bs54_PH1D 42.25~33.25.pdf page_12
# 24                      Modulus_H and G.pdf page_1
# 25                      Modulus_H and G.pdf page_2
# 26                      Modulus_H and G.pdf page_3
# 27                      Modulus_H and G.pdf page_4
# 28                      Modulus_H and G.pdf page_5
# 29                      Modulus_H and G.pdf page_6
# 30                      Modulus_H and G.pdf page_7
# 31                      Modulus_H and G.pdf page_8
# 32                      Modulus_H and G.pdf page_9
# 33                     Modulus_H and G.pdf page_10
# 34                     Modulus_H and G.pdf page_11
# 35                     Modulus_H and G.pdf page_12
# 36                     Modulus_H and G.pdf page_13
# 37                     Modulus_H and G.pdf page_14
# 38                     Modulus_H and G.pdf page_15
# 39                     Modulus_H and G.pdf page_16
# 40                          UCS_H and G.pdf page_7
