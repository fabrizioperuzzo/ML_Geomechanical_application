# %%
import numpy as np
import tabula
import pandas as pd
import PyPDF2
import re
import os
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings(action='once')

# %%
path = os.getcwd()+'\\Reports'

files = []
filespath = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.pdf' in file:
            files.append(file)
            filespath.append(os.path.join(r, file))

# %%
filespath
# Out:
# ['C:\\Users\\fpe\\JUPYTER\\datirocce\\Reports\\Rock-Test_ocr.pdf']

# %%
pdf_file = filespath[0]

df = tabula.read_pdf(pdf_file, pages='all')

# %%
df[1]

for
# Out:
#            Unnamed: 0                    I       Unnamed: 1  Unnamed: 2  \
# 0                 NaN     D ep t h  ( rn )              NaN         NaN
# 1                   #           3) From To            Layer         NaN
# 2                   1         7 . 5  7 . 8              NaN         NaN
# 3                 NaN                  NaN    Basalt, fresh         NaN
# 4                   2         9 . 0  9 . 2              NaN         NaN
# 5                   3      1 3 . 9 1 4 . 0    Pyroclastics,         NaN
# 6                   4      1 6 . 5 1 6 . 8       moderately         NaN
# 7                   5      1 9 . 7 2 0 . 0        weathered         NaN
# 8   Py roe lastics, 6     2 3 . 7  2 4 . 0              NaN         NaN
# 9                 NaN                  NaN            fresh         NaN
# 10                  7      2 5 . 1 2 5 . 4              NaN         NaN
# 11                  8     2 9 . 8  3 0 . 0              NaN         NaN
# 12                  9     3 4 . 5  3 4 . 9              NaN         NaN
# 13                1 0     3 7 . 7  3 7 . 9              NaN         NaN
# 14                1 1     3 8 . 4  3 8 . 6              NaN         NaN
# 15                1 2     4 3 . 7  4 3 . 9              NaN         NaN
# 16                1 3     4 6 . 5  4 7 . 0              NaN         NaN
# 17                1 4     5 0 . 2  5 0 . 6              NaN         NaN
# 18                NaN                  NaN    Basalt, fresh         NaN
# 19                1 5     5 2 . 3  5 2 . 9              NaN         NaN
# 20                1 6     5 6 . 4  5 6 . 8              NaN         NaN
# 21                1 7     5 8 . 6  5 8 . 9              NaN         NaN
# 22                1 8     6 0 . 0  6 0 . 2              NaN         NaN
# 23                1 9     6 4 . 2  6 4 . 4              NaN         NaN
# 24                 20     6 8 . 9  6 9 . 1              NaN         NaN
# 25                2 1      7 1 . 7 7 2 . 1              NaN         NaN
# 26                 22     7 5 . 5  7 5 . 7              NaN         NaN
# 27                 23     7 8 . 9  7 9 . 2              NaN         NaN
# 28                 24      8 1 . 6 8 2 . 3  Py roe lastics,         NaN
# 29                NaN                  NaN       moderately         NaN
# 30                 25     8 4 . 7  8 5 . 0              NaN         NaN
# 31                NaN                  NaN        weathered         NaN
# 32                 26     8 8 . 2  8 8 . 4              NaN         NaN
# 33                 27      9 1 . 7 9 2 . 0              NaN         NaN
# 34                 28     9 4 . 9  9 5 . 1    Basalt, fresh         NaN
# 35                 29      9 8 . 1 9 8 . 6              NaN         NaN
# 36                NaN                  NaN  Py roe lastics,         NaN
# 37                 30  1 0 1 . 8 1 0 2 . 3       moderately         NaN
# 38                NaN                  NaN        weathered         NaN
# 39                3 1  1 0 5 . 1 1 0 5 . 5    Basalt, fresh         NaN
# 40                 32  1 0 7 . 8 1 0 8 . 3  Py roe lastics,         NaN
# 41                 33  1 1 1 . 6 1 1 2 . 1       moderately         NaN
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7   Unnamed: 8  \
# 0           w          I         Yd         NaN          I        crucs
# 1         (%)        NaN      (kN/m         NaN        NaN        (MPa)
# 2           3        NaN    2 4 . 7         NaN        NaN          NaN
# 3         NaN        NaN        NaN         NaN        NaN          NaN
# 4           1        NaN    2 8 . 0         NaN        NaN    1 1 8 . 7
# 5           4        NaN    2 2 . 8         NaN        NaN          NaN
# 6           8        NaN    1 8 . 8         NaN        NaN      2 . 5 2
# 7           6        NaN    2 0 . 3         NaN        NaN      1 6 . 5
# 8           6        NaN    1 9 . 8         NaN        NaN    1 4 . 5 7
# 9         NaN        NaN        NaN         NaN        NaN          NaN
# 10          1        NaN    2 7 . 7         NaN        NaN    2 6 . 8 3
# 11          5        NaN    1 8 . 8         NaN        NaN    1 3 . 0 4
# 12          3        NaN    2 4 . 0         NaN        NaN    4 7 . 2 8
# 13          1        NaN    2 6 . 6         NaN        NaN    7 8 . 4 3
# 14          4        NaN    2 1 . 2         NaN        NaN      1 6 . 6
# 15          1        NaN    2 7 . 1         NaN        NaN    9 3 . 7 7
# 16          2        NaN    2 6 . 3         NaN        NaN    9 1 . 2 3
# 17          1        NaN    2 5 . 8         NaN        NaN    3 6 . 1 3
# 18        NaN        NaN        NaN         NaN        NaN          NaN
# 19          1        NaN    2 6 . 8         NaN        NaN    7 0 . 2 4
# 20          1        NaN    2 5 . 9         NaN        NaN      1 8 . 9
# 21          4        NaN    2 2 . 7         NaN        NaN      2 . 6 1
# 22          1        NaN    2 6 . 7         NaN        NaN          NaN
# 23          1        NaN    2 7 . 2         NaN        NaN    2 5 . 2 7
# 24        NaN        NaN        NaN         NaN        NaN          NaN
# 25          1        NaN    2 7 . 4         NaN        NaN  1 6 8 . 2 7
# 26          0        NaN    2 7 . 8         NaN        NaN  1 0 9 . 4 7
# 27          3        NaN    1 7 . 9         NaN        NaN          NaN
# 28          4        NaN    1 5 . 3         NaN        NaN      1 0 . 3
# 29        NaN        NaN        NaN         NaN        NaN          NaN
# 30          3        NaN    2 1 . 4         NaN        NaN      8 . 5 9
# 31        NaN        NaN        NaN         NaN        NaN          NaN
# 32          6        NaN    1 5 . 6         NaN        NaN      6 . 9 3
# 33          2        NaN    2 5 . 9         NaN        NaN      7 3 . 5
# 34          1        NaN    2 7 . 0         NaN        NaN    4 2 . 6 8
# 35          1        NaN    2 7 . 2         NaN        NaN  1 1 5 . 1 3
# 36        NaN        NaN        NaN         NaN        NaN          NaN
# 37          3        NaN    2 0 . 4         NaN        NaN      1 7 . 6
# 38        NaN        NaN        NaN         NaN        NaN          NaN
# 39          1        NaN    2 7 . 2         NaN        NaN    3 0 . 2 6
# 40          4        NaN    2 1 . 5         NaN        NaN    1 4 . 4 1
# 41          1        NaN    2 7 . 8         NaN        NaN  1 2 9 . 4 7
#
#    Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# 0           I          Es           I         NaN           v         NaN
# 1         NaN       (GPa)         NaN         NaN           -           -
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
# 5         NaN         NaN         NaN         NaN         NaN         NaN
# 6         NaN         NaN         NaN         NaN         NaN         NaN
# 7         NaN       4 . 3         NaN           0       . 1 4         NaN
# 8         NaN         NaN         NaN         NaN         NaN         NaN
# 9         NaN         NaN         NaN         NaN         NaN         NaN
# 10        NaN         NaN         NaN         NaN         NaN         NaN
# 11        NaN         NaN         NaN         NaN         NaN         NaN
# 12        NaN         NaN         NaN         NaN         NaN         NaN
# 13        NaN         NaN         NaN         NaN         NaN         NaN
# 14        NaN     1 0 . 3         NaN     0 . 2 7         NaN         NaN
# 15        NaN         NaN         NaN         NaN         NaN         NaN
# 16        NaN         NaN         NaN         NaN         NaN         NaN
# 17        NaN         NaN         NaN         NaN         NaN         NaN
# 18        NaN         NaN         NaN         NaN         NaN         NaN
# 19        NaN         NaN         NaN         NaN         NaN         NaN
# 20        NaN     4 9 . 5         NaN           0       . 1 8         NaN
# 21        NaN         NaN         NaN         NaN         NaN         NaN
# 22        NaN         NaN         NaN         NaN         NaN         NaN
# 23        NaN         NaN         NaN         NaN         NaN         NaN
# 24        NaN         NaN         NaN         NaN         NaN         NaN
# 25        NaN         NaN         NaN         NaN         NaN         NaN
# 26        NaN         NaN         NaN         NaN         NaN         NaN
# 27        NaN         NaN         NaN         NaN         NaN         NaN
# 28        NaN       4 . 9         NaN     0 . 2 6         NaN         NaN
# 29        NaN         NaN         NaN         NaN         NaN         NaN
# 30        NaN         NaN         NaN         NaN         NaN         NaN
# 31        NaN         NaN         NaN         NaN         NaN         NaN
# 32        NaN         NaN         NaN         NaN         NaN         NaN
# 33        NaN     4 3 . 3         NaN     0 . 2 4         NaN         NaN
# 34        NaN         NaN         NaN         NaN         NaN         NaN
# 35        NaN         NaN         NaN         NaN         NaN         NaN
# 36        NaN         NaN         NaN         NaN         NaN         NaN
# 37        NaN       4 . 7         NaN           0         . 1         NaN
# 38        NaN         NaN         NaN         NaN         NaN         NaN
# 39        NaN         NaN         NaN         NaN         NaN         NaN
# 40        NaN         NaN         NaN         NaN         NaN         NaN
# 41        NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 15 Unnamed: 16
# 0       lscso>           T
# 1        (MPa)       (MPa)
# 2      4 . 1 1     6 . 6 1
# 3          NaN         NaN
# 4          NaN         NaN
# 5      1 . 3 9     2 . 4 9
# 6          NaN     0 . 9 7
# 7          NaN     1 . 5 7
# 8          NaN     1 . 8 5
# 9          NaN         NaN
# 10         NaN     9 . 5 3
# 11         NaN     1 . 5 3
# 12         NaN     4 . 3 4
# 13         NaN       7 . 6
# 14         NaN     1 . 0 2
# 15         NaN         NaN
# 16         NaN     7 . 4 7
# 17         NaN   1 2 . 4 8
# 18         NaN         NaN
# 19         NaN     9 . 1 9
# 20         NaN     8 . 2 4
# 21         NaN     1 . 3 5
# 22         NaN     8 . 3 7
# 23         NaN         NaN
# 24     5 . 3 2         NaN
# 25         NaN   1 0 . 8 9
# 26         NaN   1 1 . 9 2
# 27       0 . 3     0 . 7 3
# 28         NaN     1 . 8 4
# 29         NaN         NaN
# 30         NaN     1 . 1 6
# 31         NaN         NaN
# 32         NaN         NaN
# 33         NaN     8 . 8 4
# 34         NaN         NaN
# 35         NaN       9 . 3
# 36         NaN         NaN
# 37         NaN     2 . 0 1
# 38         NaN         NaN
# 39         NaN   1 5 . 8 1
# 40         NaN     2 . 0 2
# 41         NaN   1 5 . 5 5
